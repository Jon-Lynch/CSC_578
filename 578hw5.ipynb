# %% [markdown]
# # 578hw5

# %% [markdown]
# ### Jonathan Lynch
# ### CSC 578/Section 901
# ### Homework 5

# %% [markdown]
# ## (0) Tiny experiment with One-training-One-test Iris data

# %%
import NN578_networkII as network2
import numpy as np

# Test with one-data Iris data

inst1 = (np.array([5.7, 3, 4.2, 1.2]), np.array([0., 1., 0.]))
x1 = np.reshape(inst1[0], (4, 1))
y1 = np.reshape(inst1[1], (3, 1))
sample1 = [(x1, y1)]
inst2 = (np.array([4.8, 3.4, 1.6, 0.2]), np.array([1., 0., 0.]))
x2 = np.reshape(inst2[0], (4, 1))
y2 = np.reshape(inst2[1], (3, 1))
sample2 = [(x2, y2)]

net4 = network2.load_network("iris-423.dat")
net4.set_parameters(cost=network2.QuadraticCost)

net4.SGD(sample1, 2, 1, 1.0, evaluation_data=sample2, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.26673128660052947
# Accuracy on training data: 1 / 1
# Cost on evaluation data: 0.3244002758397572
# Accuracy on evaluation data: 0 / 1
#
# Epoch 1 training complete
# Cost on training data: 0.2107866577006649
# Accuracy on training data: 1 / 1
# Cost on evaluation data: 0.37647122809828165
# Accuracy on evaluation data: 0 / 1
# ([0.26673128660052947, 0.2107866577006649],
#  [1, 1],
#  [0.3244002758397572, 0.37647122809828165],
#  [0, 0])

# %% [markdown]
# ## Load the iris_train, iris_test datasets

# %%
# Load the iris train-test (separate) data files
def my_load_csv(fname, no_trainfeatures, no_testfeatures):
    ret = np.genfromtxt(fname, delimiter=',')
    data = np.array([(entry[:no_trainfeatures],entry[no_trainfeatures:]) for entry in ret])
    temp_inputs = [np.reshape(x, (no_trainfeatures, 1)) for x in data[:,0]]
    temp_results = [np.reshape(y, (no_testfeatures, 1)) for y in data[:,1]]
    dataset = list(zip(temp_inputs, temp_results))
    return dataset

iris_train = my_load_csv('iris-train-1.csv', 4, 3)
iris_test = my_load_csv('iris-test-1.csv', 4, 3)
# Out:
# <ipython-input-2-2a5e591e3d1c>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   data = np.array([(entry[:no_trainfeatures],entry[no_trainfeatures:]) for entry in ret])

# %% [markdown]
# ## (1) Sigmoid + Sigmoid + QuadraticCost
# ### [You can run the start-up code as is to generate this.]

# %%
net2 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid)

net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.3392795030659105
# Accuracy on training data: 21 / 95
# Cost on evaluation data: 0.34444833747414394
# Accuracy on evaluation data: 15 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.3332680387432046
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3357508215659017
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.33169864345910943
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33331819877313307
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3280047701277544
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.32931297694327877
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3105024143021552
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.311452504680719
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.2822226213778409
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.28266644748693787
# Accuracy on evaluation data: 39 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.26185308519985034
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.2622221163236103
# Accuracy on evaluation data: 40 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.24637620748622577
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.24693122708939252
# Accuracy on evaluation data: 40 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.23397287354343002
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.23484243915532602
# Accuracy on evaluation data: 41 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.2240389321795399
# Accuracy on training data: 67 / 95
# Cost on evaluation data: 0.22523745295521982
# Accuracy on evaluation data: 41 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.21604989548512998
# Accuracy on training data: 70 / 95
# Cost on evaluation data: 0.2175515310927702
# Accuracy on evaluation data: 44 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.20957620155325693
# Accuracy on training data: 73 / 95
# Cost on evaluation data: 0.21134700807259035
# Accuracy on evaluation data: 47 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.2042808031846783
# Accuracy on training data: 81 / 95
# Cost on evaluation data: 0.20628846293823358
# Accuracy on evaluation data: 52 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.19990418595499362
# Accuracy on training data: 94 / 95
# Cost on evaluation data: 0.2021204428263281
# Accuracy on evaluation data: 54 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.1962475462149834
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.19864854335473608
# Accuracy on evaluation data: 35 / 55
# ([0.3392795030659105,
#   0.3332680387432046,
#   0.33169864345910943,
#   0.3280047701277544,
#   0.3105024143021552,
#   0.2822226213778409,
#   0.26185308519985034,
#   0.24637620748622577,
#   0.23397287354343002,
#   0.2240389321795399,
#   0.21604989548512998,
#   0.20957620155325693,
#   0.2042808031846783,
#   0.19990418595499362,
#   0.1962475462149834],
#  [21, 33, 33, 33, 65, 64, 65, 64, 65, 67, 70, 73, 81, 94, 65],
#  [0.34444833747414394,
#   0.3357508215659017,
#   0.33331819877313307,
#   0.32931297694327877,
#   0.311452504680719,
#   0.28266644748693787,
#   0.2622221163236103,
#   0.24693122708939252,
#   0.23484243915532602,
#   0.22523745295521982,
#   0.2175515310927702,
#   0.21134700807259035,
#   0.20628846293823358,
#   0.2021204428263281,
#   0.19864854335473608],
#  [15, 17, 17, 17, 35, 39, 40, 40, 41, 41, 44, 47, 52, 54, 35])

# %% [markdown]
# ## (2) Sigmoid + Sigmoid + CrossEntropyCost

# %% [markdown]
# __cost = CrossEntropyCost, act_hidden = Sigmoid, act_output = Sigmoid:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.CrossEntropyCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.8603802674198153
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.86801026041802
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.460606534019205
# Accuracy on training data: 69 / 95
# Cost on evaluation data: 1.4660555356377223
# Accuracy on evaluation data: 44 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.2667163241805766
# Accuracy on training data: 92 / 95
# Cost on evaluation data: 1.2774861545892018
# Accuracy on evaluation data: 54 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.1571463398823452
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.1718471307186422
# Accuracy on evaluation data: 35 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.0668798505712163
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.086639159620854
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.0269316288572257
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0468525231446604
# Accuracy on evaluation data: 35 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.0030159043215208
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0230817418856184
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.9876051818657172
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0083454504660283
# Accuracy on evaluation data: 35 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.9772276017636307
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.999039774981281
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.9690604086884841
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.9916782036368461
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.9623999454604478
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9856464279019425
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.9564443218222218
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9800468983199269
# Accuracy on evaluation data: 35 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.9519759891060914
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9761371328834579
# Accuracy on evaluation data: 34 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.9459190082319812
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9696831841725873
# Accuracy on evaluation data: 35 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.9566747295347131
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.9846220534440661
# Accuracy on evaluation data: 34 / 55
# ([1.8603802674198153,
#   1.460606534019205,
#   1.2667163241805766,
#   1.1571463398823452,
#   1.0668798505712163,
#   1.0269316288572257,
#   1.0030159043215208,
#   0.9876051818657172,
#   0.9772276017636307,
#   0.9690604086884841,
#   0.9623999454604478,
#   0.9564443218222218,
#   0.9519759891060914,
#   0.9459190082319812,
#   0.9566747295347131],
#  [33, 69, 92, 65, 65, 65, 65, 65, 65, 65, 64, 64, 64, 64, 64],
#  [1.86801026041802,
#   1.4660555356377223,
#   1.2774861545892018,
#   1.1718471307186422,
#   1.086639159620854,
#   1.0468525231446604,
#   1.0230817418856184,
#   1.0083454504660283,
#   0.999039774981281,
#   0.9916782036368461,
#   0.9856464279019425,
#   0.9800468983199269,
#   0.9761371328834579,
#   0.9696831841725873,
#   0.9846220534440661],
#  [18, 44, 54, 35, 35, 35, 35, 35, 35, 35, 35, 35, 34, 35, 34])

# %% [markdown]
# ## (3) Sigmoid + Softmax + CrossEntropyCost

# %% [markdown]
# __cost = CrossEntropyCost, act_hidden = Sigmoid, act_output = Softmax:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.CrossEntropyCost, act_hidden=network2.Sigmoid, act_output=network2.Softmax)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.8524910333322138
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 1.841215537092493
# Accuracy on evaluation data: 20 / 55
#
# Epoch 1 training complete
# Cost on training data: 2.0598310577877728
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.0738956457705893
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 2.0579394075124076
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.065183511202047
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 2.054674630318656
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.0627102215395867
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 2.023936880475182
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.039948322445991
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 2.170800056625195
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.177695518670805
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.2666769630430033
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.2808259420232888
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.1149770949675328
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 1.126018508021795
# Accuracy on evaluation data: 38 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.0546347142270678
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 1.0666988050502848
# Accuracy on evaluation data: 38 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.0226542072356246
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.035796924674432
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.0027999156295484
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.0167497814357354
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.9892904411343215
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 1.003752332805673
# Accuracy on evaluation data: 35 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.9795116363630131
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.9941810271558064
# Accuracy on evaluation data: 35 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.9719553639611375
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.9865879002863
# Accuracy on evaluation data: 35 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.9652283721054259
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.979985255120515
# Accuracy on evaluation data: 35 / 55
# ([1.8524910333322138,
#   2.0598310577877728,
#   2.0579394075124076,
#   2.054674630318656,
#   2.023936880475182,
#   2.170800056625195,
#   1.2666769630430033,
#   1.1149770949675328,
#   1.0546347142270678,
#   1.0226542072356246,
#   1.0027999156295484,
#   0.9892904411343215,
#   0.9795116363630131,
#   0.9719553639611375,
#   0.9652283721054259],
#  [30, 33, 33, 33, 33, 33, 65, 62, 62, 65, 65, 65, 65, 65, 65],
#  [1.841215537092493,
#   2.0738956457705893,
#   2.065183511202047,
#   2.0627102215395867,
#   2.039948322445991,
#   2.177695518670805,
#   1.2808259420232888,
#   1.126018508021795,
#   1.0666988050502848,
#   1.035796924674432,
#   1.0167497814357354,
#   1.003752332805673,
#   0.9941810271558064,
#   0.9865879002863,
#   0.979985255120515],
#  [20, 17, 17, 17, 17, 17, 35, 38, 38, 35, 35, 35, 35, 35, 35])

# %% [markdown]
# ## (4) Sigmoid + Softmax + LogLikelihood

# %% [markdown]
# __cost = LogLikelihood, act_hidden = Sigmoid, act_output = Softmax:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.Sigmoid, act_output=network2.Softmax)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.0725541578143791
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.0757367096860873
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.7394112289313794
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.7407176979301715
# Accuracy on evaluation data: 40 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.6205618473893993
# Accuracy on training data: 85 / 95
# Cost on evaluation data: 0.6257845728763475
# Accuracy on evaluation data: 52 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.5670736844143868
# Accuracy on training data: 93 / 95
# Cost on evaluation data: 0.5731784036177967
# Accuracy on evaluation data: 54 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.5333770349417168
# Accuracy on training data: 88 / 95
# Cost on evaluation data: 0.5400095734834602
# Accuracy on evaluation data: 54 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.5023152528399535
# Accuracy on training data: 81 / 95
# Cost on evaluation data: 0.5103342513102357
# Accuracy on evaluation data: 51 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.49562244982507947
# Accuracy on training data: 83 / 95
# Cost on evaluation data: 0.5032223921305509
# Accuracy on evaluation data: 51 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.209107753252138
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 1.1812599586020012
# Accuracy on evaluation data: 20 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.49592096704212313
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.5043047769715107
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.4817343666589516
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.4891587734008323
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.47309096708478093
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.4792400201763067
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.4770244676851744
# Accuracy on training data: 71 / 95
# Cost on evaluation data: 0.48383236398839835
# Accuracy on evaluation data: 46 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.4717382886945459
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.4783861410470161
# Accuracy on evaluation data: 35 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.6019085509547422
# Accuracy on training data: 51 / 95
# Cost on evaluation data: 0.5645536612270842
# Accuracy on evaluation data: 29 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.7069201483071614
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.7042809321452483
# Accuracy on evaluation data: 40 / 55
# ([1.0725541578143791,
#   0.7394112289313794,
#   0.6205618473893993,
#   0.5670736844143868,
#   0.5333770349417168,
#   0.5023152528399535,
#   0.49562244982507947,
#   1.209107753252138,
#   0.49592096704212313,
#   0.4817343666589516,
#   0.47309096708478093,
#   0.4770244676851744,
#   0.4717382886945459,
#   0.6019085509547422,
#   0.7069201483071614],
#  [33, 65, 85, 93, 88, 81, 83, 30, 65, 65, 65, 71, 65, 51, 64],
#  [1.0757367096860873,
#   0.7407176979301715,
#   0.6257845728763475,
#   0.5731784036177967,
#   0.5400095734834602,
#   0.5103342513102357,
#   0.5032223921305509,
#   1.1812599586020012,
#   0.5043047769715107,
#   0.4891587734008323,
#   0.4792400201763067,
#   0.48383236398839835,
#   0.4783861410470161,
#   0.5645536612270842,
#   0.7042809321452483],
#  [17, 40, 52, 54, 54, 51, 51, 20, 35, 35, 35, 46, 35, 29, 40])

# %% [markdown]
# ## (5) ReLU + Softmax + CrossEntropyCost

# %% [markdown]
# __cost = CrossEntropyCost, act_hidden = ReLU, act_output = Softmax:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.CrossEntropyCost, act_hidden=network2.ReLU, act_output=network2.Softmax)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.9109220175706492
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192231681687888
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.9109281127659505
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497719649038
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.9109281129918982
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836280689
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.9109281129902884
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353035
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.9109281129902855
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 1.9109281129902858
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353113
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 1.9109281129902866
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.9192497836353115
# Accuracy on evaluation data: 17 / 55
# ([1.9109220175706492,
#   1.9109281127659505,
#   1.9109281129918982,
#   1.9109281129902884,
#   1.9109281129902855,
#   1.9109281129902858,
#   1.9109281129902866,
#   1.9109281129902858,
#   1.9109281129902866,
#   1.9109281129902858,
#   1.9109281129902866,
#   1.9109281129902858,
#   1.9109281129902866,
#   1.9109281129902858,
#   1.9109281129902866],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33],
#  [1.9192231681687888,
#   1.9192497719649038,
#   1.9192497836280689,
#   1.9192497836353035,
#   1.9192497836353115,
#   1.9192497836353113,
#   1.9192497836353115,
#   1.9192497836353113,
#   1.9192497836353115,
#   1.9192497836353113,
#   1.9192497836353115,
#   1.9192497836353113,
#   1.9192497836353115,
#   1.9192497836353113,
#   1.9192497836353115],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17])

# %% [markdown]
# ## (6) ReLU + Softmax + LogLikelihood

# %% [markdown]
# __cost = LogLikelihood, act_hidden = ReLU, act_output = Softmax:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU, act_output=network2.Softmax)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.0978694103628626
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.10265106017516
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.0978909807841661
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031230217405117
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.097891593631602
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.103131682432255
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.097891605956821
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318413233266
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.0978916062045687
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318442875535
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.0978916062095643
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.103131844343714
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.0978916062096644
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443447928
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.0978916062096675
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.103131844344814
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 1.0978916062096673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1031318443448146
# Accuracy on evaluation data: 17 / 55
# ([1.0978694103628626,
#   1.0978909807841661,
#   1.097891593631602,
#   1.097891605956821,
#   1.0978916062045687,
#   1.0978916062095643,
#   1.0978916062096644,
#   1.0978916062096675,
#   1.0978916062096673,
#   1.0978916062096673,
#   1.0978916062096673,
#   1.0978916062096673,
#   1.0978916062096673,
#   1.0978916062096673,
#   1.0978916062096673],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33],
#  [1.10265106017516,
#   1.1031230217405117,
#   1.103131682432255,
#   1.1031318413233266,
#   1.1031318442875535,
#   1.103131844343714,
#   1.1031318443447928,
#   1.103131844344814,
#   1.1031318443448146,
#   1.1031318443448146,
#   1.1031318443448146,
#   1.1031318443448146,
#   1.1031318443448146,
#   1.1031318443448146,
#   1.1031318443448146],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17])

# %% [markdown]
# ## (7) Tanh + Sigmoid + QuadraticCost

# %% [markdown]
# __cost = QuadraticCost, act_hidden = Tanh, act_output = Sigmoid:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Tanh, act_output=network2.Sigmoid)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.33443116540231776
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3363579316611686
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.33175799332119593
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33326213908032815
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.2888319510914468
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.28986158907272574
# Accuracy on evaluation data: 38 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.2187945048778968
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.21994496188727217
# Accuracy on evaluation data: 38 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.19532043187167236
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1975753300018062
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.1855297148025347
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1885132641215318
# Accuracy on evaluation data: 35 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.18041560683139668
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.18380157993229201
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.17730855793255562
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.18092380021642965
# Accuracy on evaluation data: 35 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.17523125989906965
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17898859908100612
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.17375076811304133
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1776028110886066
# Accuracy on evaluation data: 35 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.172645711732782
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17656425232755787
# Accuracy on evaluation data: 35 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.17179130790365216
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1757584405091967
# Accuracy on evaluation data: 35 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.17111209145146636
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1751159110291929
# Accuracy on evaluation data: 35 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.17055987550890314
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17459216589672671
# Accuracy on evaluation data: 35 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.17010251863919207
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1741574243227054
# Accuracy on evaluation data: 35 / 55
# ([0.33443116540231776,
#   0.33175799332119593,
#   0.2888319510914468,
#   0.2187945048778968,
#   0.19532043187167236,
#   0.1855297148025347,
#   0.18041560683139668,
#   0.17730855793255562,
#   0.17523125989906965,
#   0.17375076811304133,
#   0.172645711732782,
#   0.17179130790365216,
#   0.17111209145146636,
#   0.17055987550890314,
#   0.17010251863919207],
#  [32, 33, 62, 62, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65, 65],
#  [0.3363579316611686,
#   0.33326213908032815,
#   0.28986158907272574,
#   0.21994496188727217,
#   0.1975753300018062,
#   0.1885132641215318,
#   0.18380157993229201,
#   0.18092380021642965,
#   0.17898859908100612,
#   0.1776028110886066,
#   0.17656425232755787,
#   0.1757584405091967,
#   0.1751159110291929,
#   0.17459216589672671,
#   0.1741574243227054],
#  [18, 17, 38, 38, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35])

# %% [markdown]
# ## (8) Tanh + Tanh + QuadraticCost

# %% [markdown]
# __cost = QuadraticCost, act_hidden = Tanh, act_output = Tanh:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Tanh, act_output=network2.Tanh)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.563233530176793
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.6447817575121673
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.7700632291151863
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.844984887702774
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.5001812828566978
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5351845062571425
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.5570778587128011
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5640765578671585
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.4008025521130152
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.4146963617649189
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.7515323812802583
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.8225619187762778
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.6150277986763806
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 1.5628155809926998
# Accuracy on evaluation data: 20 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.61285966870343
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.64503349929495
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.513455038718176
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5728424445902927
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.7513250580269917
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.8214007989695085
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 1.449075488504673
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.4702886010586245
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 1.5583532379240317
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.565062517390935
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 1.4579791597209628
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5021202391858304
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 1.574436629556245
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.5905691516276612
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 1.4493281226024253
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.4643254632786735
# Accuracy on evaluation data: 17 / 55
# ([1.563233530176793,
#   1.7700632291151863,
#   1.5001812828566978,
#   1.5570778587128011,
#   1.4008025521130152,
#   1.7515323812802583,
#   1.6150277986763806,
#   1.61285966870343,
#   1.513455038718176,
#   1.7513250580269917,
#   1.449075488504673,
#   1.5583532379240317,
#   1.4579791597209628,
#   1.574436629556245,
#   1.4493281226024253],
#  [33, 33, 33, 33, 33, 33, 30, 33, 33, 33, 33, 33, 33, 33, 33],
#  [1.6447817575121673,
#   1.844984887702774,
#   1.5351845062571425,
#   1.5640765578671585,
#   1.4146963617649189,
#   1.8225619187762778,
#   1.5628155809926998,
#   1.64503349929495,
#   1.5728424445902927,
#   1.8214007989695085,
#   1.4702886010586245,
#   1.565062517390935,
#   1.5021202391858304,
#   1.5905691516276612,
#   1.4643254632786735],
#  [17, 17, 17, 17, 17, 17, 20, 17, 17, 17, 17, 17, 17, 17, 17])

# %% [markdown]
# ## (9) Sigmoid + Sigmoid + QuadraticCost (L2 regularization & lambda = 3.0)

# %% [markdown]
# __cost = QuadraticCost, act_hidden = Sigmoid, act_output = Sigmoid, regularization = L2, lmbda = 3.0:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid, 
                   regularization= 'L2', lmbda = 3.0)
net2.SGD(iris_train, 15, 10, 1.0, 3.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.45886398333113254
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.5509298016398527
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.396623357612462
# Accuracy on training data: 31 / 95
# Cost on evaluation data: 0.4441627862193589
# Accuracy on evaluation data: 20 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.35964315066025077
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.38666765720485874
# Accuracy on evaluation data: 38 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.34262845791173324
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.36158436118873444
# Accuracy on evaluation data: 38 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3341612302254376
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.35010483170635776
# Accuracy on evaluation data: 38 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.32949877244802633
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.34509465468848194
# Accuracy on evaluation data: 38 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.3266100283714264
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3430922517975508
# Accuracy on evaluation data: 38 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.3246207815335592
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.34246860387826106
# Accuracy on evaluation data: 38 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.32317949516790373
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3425544533429334
# Accuracy on evaluation data: 38 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.3221101647238849
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.3430183499957253
# Accuracy on evaluation data: 38 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.3213076417081684
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.34366623702130267
# Accuracy on evaluation data: 39 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.3207007860256327
# Accuracy on training data: 63 / 95
# Cost on evaluation data: 0.3443769166605408
# Accuracy on evaluation data: 39 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.32023794744722905
# Accuracy on training data: 66 / 95
# Cost on evaluation data: 0.3450754538270464
# Accuracy on evaluation data: 42 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.3198807020878355
# Accuracy on training data: 71 / 95
# Cost on evaluation data: 0.3457187003821496
# Accuracy on evaluation data: 44 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.31960052304643904
# Accuracy on training data: 74 / 95
# Cost on evaluation data: 0.34628541820429487
# Accuracy on evaluation data: 47 / 55
# ([0.45886398333113254,
#   0.396623357612462,
#   0.35964315066025077,
#   0.34262845791173324,
#   0.3341612302254376,
#   0.32949877244802633,
#   0.3266100283714264,
#   0.3246207815335592,
#   0.32317949516790373,
#   0.3221101647238849,
#   0.3213076417081684,
#   0.3207007860256327,
#   0.32023794744722905,
#   0.3198807020878355,
#   0.31960052304643904],
#  [30, 31, 62, 62, 62, 62, 62, 62, 62, 62, 62, 63, 66, 71, 74],
#  [0.5509298016398527,
#   0.4441627862193589,
#   0.38666765720485874,
#   0.36158436118873444,
#   0.35010483170635776,
#   0.34509465468848194,
#   0.3430922517975508,
#   0.34246860387826106,
#   0.3425544533429334,
#   0.3430183499957253,
#   0.34366623702130267,
#   0.3443769166605408,
#   0.3450754538270464,
#   0.3457187003821496,
#   0.34628541820429487],
#  [18, 20, 38, 38, 38, 38, 38, 38, 38, 38, 39, 39, 42, 44, 47])

# %% [markdown]
# ## (10) Sigmoid + Sigmoid + QuadraticCost (L1 regularization & lambda = 3.0)

# %% [markdown]
# __cost = QuadraticCost, act_hidden = Sigmoid, act_output = Sigmoid, reularization = L1, lmbda = 3.0:__

# %%
net2 = network2.load_network("iris-423.dat")
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid, 
                   regularization= 'L1', lmbda = 3.0)
net2.SGD(iris_train, 15, 10, 1.0, 3.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.4516053196093104
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.5374617866414568
# Accuracy on evaluation data: 35 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.41428347475756044
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.46861558765087574
# Accuracy on evaluation data: 20 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.3866791709124658
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.4218431508911809
# Accuracy on evaluation data: 20 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3634416932952713
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.3821846121414242
# Accuracy on evaluation data: 20 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3446605897831082
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.35202748363693376
# Accuracy on evaluation data: 20 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.3363075898372987
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.33822059894780876
# Accuracy on evaluation data: 20 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.33596243258632863
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3384137311125946
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.3360898156409818
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33914817321851404
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.3366808593678425
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.34030398989939614
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.336955803799634
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.34089990631988937
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.33723602525372964
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3414486770245466
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.33680017586214994
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.34087363752219596
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.33674488127739977
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.340776371875123
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.3366404842457893
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3405471432220803
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.33687366594302376
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3409990129979146
# Accuracy on evaluation data: 17 / 55
# ([0.4516053196093104,
#   0.41428347475756044,
#   0.3866791709124658,
#   0.3634416932952713,
#   0.3446605897831082,
#   0.3363075898372987,
#   0.33596243258632863,
#   0.3360898156409818,
#   0.3366808593678425,
#   0.336955803799634,
#   0.33723602525372964,
#   0.33680017586214994,
#   0.33674488127739977,
#   0.3366404842457893,
#   0.33687366594302376],
#  [65, 30, 30, 30, 30, 30, 33, 33, 33, 33, 33, 33, 33, 33, 33],
#  [0.5374617866414568,
#   0.46861558765087574,
#   0.4218431508911809,
#   0.3821846121414242,
#   0.35202748363693376,
#   0.33822059894780876,
#   0.3384137311125946,
#   0.33914817321851404,
#   0.34030398989939614,
#   0.34089990631988937,
#   0.3414486770245466,
#   0.34087363752219596,
#   0.340776371875123,
#   0.3405471432220803,
#   0.3409990129979146],
#  [35, 20, 20, 20, 20, 20, 17, 17, 17, 17, 17, 17, 17, 17, 17])

# %% [markdown]
# ## (11) Sigmoid + Sigmoid + QuadraticCost (dropout = 0.1)

# %% [markdown]
# __cost = QuadraticCost, act_hidden = Sigmoid, act_output = Sigmoid, dropoutpercent = 0.1:__

# %%
net2 = network2.load_network("iris4-20-7-3.dat")
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid,
                    dropoutpercent = 0.1)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.3335740943503786
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33404687074352263
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.3331995811844022
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3341772387932944
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.3330432158573106
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33409648633707717
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.33290329486932896
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33398372240733104
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3327509363140008
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3338058725644908
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.33252841558709817
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33356081467423127
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.3323766978118621
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33340528550764975
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.33211227706700547
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33307682527790095
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.331794015440399
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3326742620886638
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.3312979063788147
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33210859780858715
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.33057795665568723
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3312815995326168
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.3294999518443511
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33004692067316077
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.3279973680797629
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3283118670736086
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.3262081924862565
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.32636541600470664
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.324228143599657
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3243782211400257
# Accuracy on evaluation data: 17 / 55
# ([0.3335740943503786,
#   0.3331995811844022,
#   0.3330432158573106,
#   0.33290329486932896,
#   0.3327509363140008,
#   0.33252841558709817,
#   0.3323766978118621,
#   0.33211227706700547,
#   0.331794015440399,
#   0.3312979063788147,
#   0.33057795665568723,
#   0.3294999518443511,
#   0.3279973680797629,
#   0.3262081924862565,
#   0.324228143599657],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33],
#  [0.33404687074352263,
#   0.3341772387932944,
#   0.33409648633707717,
#   0.33398372240733104,
#   0.3338058725644908,
#   0.33356081467423127,
#   0.33340528550764975,
#   0.33307682527790095,
#   0.3326742620886638,
#   0.33210859780858715,
#   0.3312815995326168,
#   0.33004692067316077,
#   0.3283118670736086,
#   0.32636541600470664,
#   0.3243782211400257],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17])

# %% [markdown]
# ## (12) Sigmoid + Sigmoid + QuadraticCost (dropout = 0.5)

# %% [markdown]
# __cost = QuadraticCost, act_hidden = Sigmoid, act_output = Sigmoid, dropoutpercent = 0.5:__

# %%
net2 = network2.load_network("iris4-20-7-3.dat")
net2.set_parameters(cost=network2.QuadraticCost, act_hidden=network2.Sigmoid, act_output=network2.Sigmoid,
                    dropoutpercent = 0.5)
net2.SGD(iris_train, 15, 10, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.33341659481686137
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33430579088260337
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.33320566424482656
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3342623864352013
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.3331053448263062
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3342366208764165
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3329860558671439
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33410652126107593
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3327985732626171
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33388649612253685
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.332625799287642
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3336978841492848
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.3323893890218933
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3334163611710141
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.332116851531823
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3330562483854569
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.3314652735381048
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33225858145999654
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.3314050669451763
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3322193885619482
# Accuracy on evaluation data: 17 / 55
#
# Epoch 10 training complete
# Cost on training data: 0.33122988102249384
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33207613002987807
# Accuracy on evaluation data: 17 / 55
#
# Epoch 11 training complete
# Cost on training data: 0.32999814400391053
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33073556628909334
# Accuracy on evaluation data: 17 / 55
#
# Epoch 12 training complete
# Cost on training data: 0.32983971624334235
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.33058447724108175
# Accuracy on evaluation data: 17 / 55
#
# Epoch 13 training complete
# Cost on training data: 0.3298236053119242
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3306609295276078
# Accuracy on evaluation data: 17 / 55
#
# Epoch 14 training complete
# Cost on training data: 0.32964194751785236
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 0.3303888352122814
# Accuracy on evaluation data: 17 / 55
# ([0.33341659481686137,
#   0.33320566424482656,
#   0.3331053448263062,
#   0.3329860558671439,
#   0.3327985732626171,
#   0.332625799287642,
#   0.3323893890218933,
#   0.332116851531823,
#   0.3314652735381048,
#   0.3314050669451763,
#   0.33122988102249384,
#   0.32999814400391053,
#   0.32983971624334235,
#   0.3298236053119242,
#   0.32964194751785236],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33],
#  [0.33430579088260337,
#   0.3342623864352013,
#   0.3342366208764165,
#   0.33410652126107593,
#   0.33388649612253685,
#   0.3336978841492848,
#   0.3334163611710141,
#   0.3330562483854569,
#   0.33225858145999654,
#   0.3322193885619482,
#   0.33207613002987807,
#   0.33073556628909334,
#   0.33058447724108175,
#   0.3306609295276078,
#   0.3303888352122814],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17])
